# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
   
# Read an image
inputImage = cv2.imread('../images/kath_golap.jpeg')
   
# Apply log transformation method
c = 255 / np.log(1 + np.max(inputImage))
log_image = c * (np.log(inputImage + 1))
   
log_image = np.array(log_image, dtype = np.uint8)
   
# Display both images
plt.imshow(inputImage)
plt.show()

plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_6132/1114319913.py:10: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(inputImage + 1))
